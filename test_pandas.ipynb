# %%
import pandas as pd

# %%
df = pd.read_excel("EventSchedule.xlsx", sheet_name="Sheet1")
df.head()
# Out:
#         Date StartTime   EndTime                 EventName  \
# 0 2025-10-28  09:00:00  11:30:00     Community Health Fair
# 1 2025-10-29  13:00:00  15:00:00  Corporate Wellness Check
# 2 2025-11-05  10:00:00  12:00:00           Flu Shot Clinic
# 3 2025-11-05  14:00:00  16:00:00   Senior Health Screening
#
#                   Location  IsPrivate
# 0    Central Park Pavilion      False
# 1         123 Business Rd.       True
# 2      City Hall Courtyard      False
# 3  Northwood Senior Center      False
